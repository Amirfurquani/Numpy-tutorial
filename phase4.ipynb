# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
array1=np.array([1,2,3,4,5])
array2=np.random.rand(3,3)
array3=np.zeros((4,4))

# %%
np.save('array1',array1)
np.save('array2',array2)
np.save('array3',array3)

# %%
loaded_array1=np.load('array1.npy')
print(loaded_array1)
# Out:
# [1 2 3 4 5]

# %%
from PIL import Image
import numpy as np

img = Image.open(r"C:\Users\syedm\OneDrive\Attachments\Desktop\MAIN\amiir\amiir\Amir Document\amir formal.jpeg")

img_array = np.array(img)

np.save("image.npy", img_array)

print("Image converted successfully!")
# Out:
# Image converted successfully!

# %%
try:
    image1=np.load("image.npy")

#display
    plt.figure(figsize=(10,25))
    plt.subplot(121)
    plt.imshow(image1)
    plt.title("my image")
    plt.grid(False)

    #for dark plot
    dark_image=1-image1

    
    plt.subplot(122)
    plt.imshow(dark_image)
    plt.title("my  dark image")
    plt.grid(False)



except FileNotFoundError:
    print("not found")
